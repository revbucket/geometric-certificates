# %%
import numpy as np
from plnn import PLNN
import torch
import torch.nn as nn
import torch.optim as optim
from torch.autograd import Variable
import utilities as utils
# Out:
# /home/justin/Programs/anaconda3/envs/DeepL/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:107: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
# ==================================
# Generate Training Points
# ==================================

print('===============Generating Training Points============')
# random points at least 2r apart
m = 12
np.random.seed(3)
x = [np.random.uniform(size=(2))]
r = 0.16
while(len(x) < m):
    p = np.random.uniform(size=(2))
    if min(np.abs(p-a).sum() for a in x) > 2*r:
        x.append(p)
# r = 0.145
epsilon = r/2

X = torch.Tensor(np.array(x))
torch.manual_seed(1)
y = (torch.rand(m)+0.5).long()
# Out:
# ===============Generating Training Points============

# %%
# ===========================================
# Experimental Loop
# ===========================================
layer_nums = [elem for elem in range(0, 10)]
errs = []
unique_polytopes = []

for layer_num in layer_nums:
    layer_sizes = [2, 20] + [4 for _ in range(0, layer_num)] + [2]

    # ==================================
    # Initialize Network
    # ==================================
    
    print('===============Initializing Network============')
    network = PLNN(layer_sizes)
    net = network.net
    
    # ==================================
    # Train Network
    # ==================================
    
    print('===============Training Network============')
    opt = optim.Adam(net.parameters(), lr=1e-3)
    for i in range(1000):
        out = net(Variable(X))
        l = nn.CrossEntropyLoss()(out, Variable(y))
        err = (out.max(1)[1].data != y).float().mean()
        opt.zero_grad()
        (l).backward()
        opt.step()
    errs.append(err)
    print('error: ', err)
    
    # ==================================
    # Gather Polytopes
    # ==================================
    print('===============Gathering Polytopes============')
    num_pts = 250
    xylim = 1.0
    
    unique_relu_configs_list, unique_bin_acts, _, _ = utils.get_unique_relu_configs(network, xylim, num_pts)
    unique_polytopes.append(len(unique_bin_acts))
    print('number of polytopes:', len(unique_bin_acts))
# Out:
# ===============Initializing Network============
# Sequential(
#   (1): Linear(in_features=2, out_features=20, bias=True)
#   (2): ReLU()
#   (3): Linear(in_features=20, out_features=2, bias=True)
# )
# ===============Training Network============
# error:  tensor(0.2500)
# ===============Gathering Network============
# number of polytopes: 15
# ===============Initializing Network============
# Sequential(
#   (1): Linear(in_features=2, out_features=20, bias=True)
#   (2): ReLU()
#   (3): Linear(in_features=20, out_features=4, bias=True)
#   (4): ReLU()
#   (5): Linear(in_features=4, out_features=2, bias=True)
# )
# ===============Training Network============
# error:  tensor(0.2500)
# ===============Gathering Network============
# number of polytopes: 25
# ===============Initializing Network============
# Sequential(
#   (1): Linear(in_features=2, out_features=20, bias=True)
#   (2): ReLU()
#   (3): Linear(in_features=20, out_features=4, bias=True)
#   (4): ReLU()
#   (5): Linear(in_features=4, out_features=4, bias=True)
#   (6): ReLU()
#   (7): Linear(in_features=4, out_features=2, bias=True)
# )
# ===============Training Network============
# error:  tensor(0.)
# ===============Gathering Network============
# number of polytopes: 26
# ===============Initializing Network============
# Sequential(
#   (1): Linear(in_features=2, out_features=20, bias=True)
#   (2): ReLU()
#   (3): Linear(in_features=20, out_features=4, bias=True)
#   (4): ReLU()
#   (5): Linear(in_features=4, out_features=4, bias=True)
#   (6): ReLU()
#   (7): Linear(in_features=4, out_features=4, bias=True)
#   (8): ReLU()
#   (9): Linear(in_features=4, out_features=2, bias=True)
# )
# ===============Training Network============
# error:  tensor(0.)
# ===============Gathering Network============
# number of polytopes: 80
# ===============Initializing Network============
# Sequential(
#   (1): Linear(in_features=2, out_features=20, bias=True)
#   (2): ReLU()
#   (3): Linear(in_features=20, out_features=4, bias=True)
#   (4): ReLU()
#   (5): Linear(in_features=4, out_features=4, bias=True)
#   (6): ReLU()
#   (7): Linear(in_features=4, out_features=4, bias=True)
#   (8): ReLU()
#   (9): Linear(in_features=4, out_features=4, bias=True)
#   (10): ReLU()
#   (11): Linear(in_features=4, out_features=2, bias=True)
# )
# ===============Training Network============
# error:  tensor(1.00000e-02 *
#        8.3333)
# ===============Gathering Network============
# number of polytopes: 38
# ===============Initializing Network============
# Sequential(
#   (1): Linear(in_features=2, out_features=20, bias=True)
#   (2): ReLU()
#   (3): Linear(in_features=20, out_features=4, bias=True)
#   (4): ReLU()
#   (5): Linear(in_features=4, out_features=4, bias=True)
#   (6): ReLU()
#   (7): Linear(in_features=4, out_features=4, bias=True)
#   (8): ReLU()
#   (9): Linear(in_features=4, out_features=4, bias=True)
#   (10): ReLU()
#   (11): Linear(in_features=4, out_features=4, bias=True)
#   (12): ReLU()
#   (13): Linear(in_features=4, out_features=2, bias=True)
# )
# ===============Training Network============
# error:  tensor(0.2500)
# ===============Gathering Network============
# number of polytopes: 45
# ===============Initializing Network============
# Sequential(
#   (1): Linear(in_features=2, out_features=20, bias=True)
#   (2): ReLU()
#   (3): Linear(in_features=20, out_features=4, bias=True)
#   (4): ReLU()
#   (5): Linear(in_features=4, out_features=4, bias=True)
#   (6): ReLU()
#   (7): Linear(in_features=4, out_features=4, bias=True)
#   (8): ReLU()
#   (9): Linear(in_features=4, out_features=4, bias=True)
#   (10): ReLU()
#   (11): Linear(in_features=4, out_features=4, bias=True)
#   (12): ReLU()
#   (13): Linear(in_features=4, out_features=4, bias=True)
#   (14): ReLU()
#   (15): Linear(in_features=4, out_features=2, bias=True)
# )
# ===============Training Network============
# error:  tensor(1.00000e-02 *
#        8.3333)
# ===============Gathering Network============
# number of polytopes: 64
# ===============Initializing Network============
# Sequential(
#   (1): Linear(in_features=2, out_features=20, bias=True)
#   (2): ReLU()
#   (3): Linear(in_features=20, out_features=4, bias=True)
#   (4): ReLU()
#   (5): Linear(in_features=4, out_features=4, bias=True)
#   (6): ReLU()
#   (7): Linear(in_features=4, out_features=4, bias=True)
#   (8): ReLU()
#   (9): Linear(in_features=4, out_features=4, bias=True)
#   (10): ReLU()
#   (11): Linear(in_features=4, out_features=4, bias=True)
#   (12): ReLU()
#   (13): Linear(in_features=4, out_features=4, bias=True)
#   (14): ReLU()
#   (15): Linear(in_features=4, out_features=4, bias=True)
#   (16): ReLU()
#   (17): Linear(in_features=4, out_features=2, bias=True)
# )
# ===============Training Network============
# error:  tensor(0.4167)
# ===============Gathering Network============
# number of polytopes: 67
# ===============Initializing Network============
# Sequential(
#   (1): Linear(in_features=2, out_features=20, bias=True)
#   (2): ReLU()
#   (3): Linear(in_features=20, out_features=4, bias=True)
#   (4): ReLU()
#   (5): Linear(in_features=4, out_features=4, bias=True)
#   (6): ReLU()
#   (7): Linear(in_features=4, out_features=4, bias=True)
#   (8): ReLU()
#   (9): Linear(in_features=4, out_features=4, bias=True)
#   (10): ReLU()
#   (11): Linear(in_features=4, out_features=4, bias=True)
#   (12): ReLU()
#   (13): Linear(in_features=4, out_features=4, bias=True)
#   (14): ReLU()
#   (15): Linear(in_features=4, out_features=4, bias=True)
#   (16): ReLU()
#   (17): Linear(in_features=4, out_features=4, bias=True)
#   (18): ReLU()
#   (19): Linear(in_features=4, out_features=2, bias=True)
# )
# ===============Training Network============
# error:  tensor(0.1667)
# ===============Gathering Network============
# number of polytopes: 140
# ===============Initializing Network============
# Sequential(
#   (1): Linear(in_features=2, out_features=20, bias=True)
#   (2): ReLU()
#   (3): Linear(in_features=20, out_features=4, bias=True)
#   (4): ReLU()
#   (5): Linear(in_features=4, out_features=4, bias=True)
#   (6): ReLU()
#   (7): Linear(in_features=4, out_features=4, bias=True)
#   (8): ReLU()
#   (9): Linear(in_features=4, out_features=4, bias=True)
#   (10): ReLU()
#   (11): Linear(in_features=4, out_features=4, bias=True)
#   (12): ReLU()
#   (13): Linear(in_features=4, out_features=4, bias=True)
#   (14): ReLU()
#   (15): Linear(in_features=4, out_features=4, bias=True)
#   (16): ReLU()
#   (17): Linear(in_features=4, out_features=4, bias=True)
#   (18): ReLU()
#   (19): Linear(in_features=4, out_features=4, bias=True)
#   (20): ReLU()
#   (21): Linear(in_features=4, out_features=2, bias=True)
# )
# ===============Training Network============
# error:  tensor(0.4167)
# ===============Gathering Network============
# number of polytopes: 19

# %%
# ===========================================
# Experimental Loop 2
# ===========================================
widths = [int(elem) for elem in np.linspace(6, 100, 15)]
errs = []
unique_polytopes = []

for width in widths:
    layer_sizes = [2] + [width for _ in range(0, 4)] + [2]

    # ==================================
    # Initialize Network
    # ==================================
    
    print('===============Initializing Network============')
    network = PLNN(layer_sizes)
    net = network.net
    
    # ==================================
    # Train Network
    # ==================================
    
    print('===============Training Network============')
    opt = optim.Adam(net.parameters(), lr=1e-3)
    for i in range(1000):
        out = net(Variable(X))
        l = nn.CrossEntropyLoss()(out, Variable(y))
        err = (out.max(1)[1].data != y).float().mean()
        opt.zero_grad()
        (l).backward()
        opt.step()
    errs.append(err)
    print('error: ', err)
    
    # ==================================
    # Gather Polytopes
    # ==================================
    print('===============Gathering Polytopes============')
    num_pts = 350
    xylim = 1.0
    
    unique_relu_configs_list, unique_bin_acts, _, _ = utils.get_unique_relu_configs(network, xylim, num_pts)
    unique_polytopes.append(len(unique_bin_acts))
    print('number of polytopes:', len(unique_bin_acts))
# Out:
# ===============Initializing Network============
# Sequential(
#   (1): Linear(in_features=2, out_features=6, bias=True)
#   (2): ReLU()
#   (3): Linear(in_features=6, out_features=6, bias=True)
#   (4): ReLU()
#   (5): Linear(in_features=6, out_features=6, bias=True)
#   (6): ReLU()
#   (7): Linear(in_features=6, out_features=6, bias=True)
#   (8): ReLU()
#   (9): Linear(in_features=6, out_features=2, bias=True)
# )
# ===============Training Network============
# error:  tensor(0.2500)
# ===============Gathering Network============
# number of polytopes: 24
# ===============Initializing Network============
# Sequential(
#   (1): Linear(in_features=2, out_features=12, bias=True)
#   (2): ReLU()
#   (3): Linear(in_features=12, out_features=12, bias=True)
#   (4): ReLU()
#   (5): Linear(in_features=12, out_features=12, bias=True)
#   (6): ReLU()
#   (7): Linear(in_features=12, out_features=12, bias=True)
#   (8): ReLU()
#   (9): Linear(in_features=12, out_features=2, bias=True)
# )
# ===============Training Network============
# error:  tensor(0.)
# ===============Gathering Network============
# number of polytopes: 47
# ===============Initializing Network============
# Sequential(
#   (1): Linear(in_features=2, out_features=19, bias=True)
#   (2): ReLU()
#   (3): Linear(in_features=19, out_features=19, bias=True)
#   (4): ReLU()
#   (5): Linear(in_features=19, out_features=19, bias=True)
#   (6): ReLU()
#   (7): Linear(in_features=19, out_features=19, bias=True)
#   (8): ReLU()
#   (9): Linear(in_features=19, out_features=2, bias=True)
# )
# ===============Training Network============
# error:  tensor(0.)
# ===============Gathering Network============
# number of polytopes: 225
# ===============Initializing Network============
# Sequential(
#   (1): Linear(in_features=2, out_features=26, bias=True)
#   (2): ReLU()
#   (3): Linear(in_features=26, out_features=26, bias=True)
#   (4): ReLU()
#   (5): Linear(in_features=26, out_features=26, bias=True)
#   (6): ReLU()
#   (7): Linear(in_features=26, out_features=26, bias=True)
#   (8): ReLU()
#   (9): Linear(in_features=26, out_features=2, bias=True)
# )
# ===============Training Network============
# error:  tensor(0.)
# ===============Gathering Network============
# number of polytopes: 255
# ===============Initializing Network============
# Sequential(
#   (1): Linear(in_features=2, out_features=32, bias=True)
#   (2): ReLU()
#   (3): Linear(in_features=32, out_features=32, bias=True)
#   (4): ReLU()
#   (5): Linear(in_features=32, out_features=32, bias=True)
#   (6): ReLU()
#   (7): Linear(in_features=32, out_features=32, bias=True)
#   (8): ReLU()
#   (9): Linear(in_features=32, out_features=2, bias=True)
# )
# ===============Training Network============
# error:  tensor(0.)
# ===============Gathering Network============
# number of polytopes: 712
# ===============Initializing Network============
# Sequential(
#   (1): Linear(in_features=2, out_features=39, bias=True)
#   (2): ReLU()
#   (3): Linear(in_features=39, out_features=39, bias=True)
#   (4): ReLU()
#   (5): Linear(in_features=39, out_features=39, bias=True)
#   (6): ReLU()
#   (7): Linear(in_features=39, out_features=39, bias=True)
#   (8): ReLU()
#   (9): Linear(in_features=39, out_features=2, bias=True)
# )
# ===============Training Network============
# error:  tensor(0.)
# ===============Gathering Network============
# number of polytopes: 1203
# ===============Initializing Network============
# Sequential(
#   (1): Linear(in_features=2, out_features=46, bias=True)
#   (2): ReLU()
#   (3): Linear(in_features=46, out_features=46, bias=True)
#   (4): ReLU()
#   (5): Linear(in_features=46, out_features=46, bias=True)
#   (6): ReLU()
#   (7): Linear(in_features=46, out_features=46, bias=True)
#   (8): ReLU()
#   (9): Linear(in_features=46, out_features=2, bias=True)
# )
# ===============Training Network============
# error:  tensor(0.)
# ===============Gathering Network============
# number of polytopes: 579
# ===============Initializing Network============
# Sequential(
#   (1): Linear(in_features=2, out_features=53, bias=True)
#   (2): ReLU()
#   (3): Linear(in_features=53, out_features=53, bias=True)
#   (4): ReLU()
#   (5): Linear(in_features=53, out_features=53, bias=True)
#   (6): ReLU()
#   (7): Linear(in_features=53, out_features=53, bias=True)
#   (8): ReLU()
#   (9): Linear(in_features=53, out_features=2, bias=True)
# )
# ===============Training Network============
# error:  tensor(0.)
# ===============Gathering Network============
# number of polytopes: 1547
# ===============Initializing Network============
# Sequential(
#   (1): Linear(in_features=2, out_features=59, bias=True)
#   (2): ReLU()
#   (3): Linear(in_features=59, out_features=59, bias=True)
#   (4): ReLU()
#   (5): Linear(in_features=59, out_features=59, bias=True)
#   (6): ReLU()
#   (7): Linear(in_features=59, out_features=59, bias=True)
#   (8): ReLU()
#   (9): Linear(in_features=59, out_features=2, bias=True)
# )
# ===============Training Network============
# error:  tensor(0.)
# ===============Gathering Network============
# number of polytopes: 1940
# ===============Initializing Network============
# Sequential(
#   (1): Linear(in_features=2, out_features=66, bias=True)
#   (2): ReLU()
#   (3): Linear(in_features=66, out_features=66, bias=True)
#   (4): ReLU()
#   (5): Linear(in_features=66, out_features=66, bias=True)
#   (6): ReLU()
#   (7): Linear(in_features=66, out_features=66, bias=True)
#   (8): ReLU()
#   (9): Linear(in_features=66, out_features=2, bias=True)
# )
# ===============Training Network============
# error:  tensor(0.)
# ===============Gathering Network============
# number of polytopes: 2338
# ===============Initializing Network============
# Sequential(
#   (1): Linear(in_features=2, out_features=73, bias=True)
#   (2): ReLU()
#   (3): Linear(in_features=73, out_features=73, bias=True)
#   (4): ReLU()
#   (5): Linear(in_features=73, out_features=73, bias=True)
#   (6): ReLU()
#   (7): Linear(in_features=73, out_features=73, bias=True)
#   (8): ReLU()
#   (9): Linear(in_features=73, out_features=2, bias=True)
# )
# ===============Training Network============
# error:  tensor(0.)
# ===============Gathering Network============
# number of polytopes: 1168
# ===============Initializing Network============
# Sequential(
#   (1): Linear(in_features=2, out_features=79, bias=True)
#   (2): ReLU()
#   (3): Linear(in_features=79, out_features=79, bias=True)
#   (4): ReLU()
#   (5): Linear(in_features=79, out_features=79, bias=True)
#   (6): ReLU()
#   (7): Linear(in_features=79, out_features=79, bias=True)
#   (8): ReLU()
#   (9): Linear(in_features=79, out_features=2, bias=True)
# )
# ===============Training Network============
# error:  tensor(0.)
# ===============Gathering Network============
# number of polytopes: 2443
# ===============Initializing Network============
# Sequential(
#   (1): Linear(in_features=2, out_features=86, bias=True)
#   (2): ReLU()
#   (3): Linear(in_features=86, out_features=86, bias=True)
#   (4): ReLU()
#   (5): Linear(in_features=86, out_features=86, bias=True)
#   (6): ReLU()
#   (7): Linear(in_features=86, out_features=86, bias=True)
#   (8): ReLU()
#   (9): Linear(in_features=86, out_features=2, bias=True)
# )
# ===============Training Network============
# error:  tensor(0.)
# ===============Gathering Network============
# number of polytopes: 2592
# ===============Initializing Network============
# Sequential(
#   (1): Linear(in_features=2, out_features=93, bias=True)
#   (2): ReLU()
#   (3): Linear(in_features=93, out_features=93, bias=True)
#   (4): ReLU()
#   (5): Linear(in_features=93, out_features=93, bias=True)
#   (6): ReLU()
#   (7): Linear(in_features=93, out_features=93, bias=True)
#   (8): ReLU()
#   (9): Linear(in_features=93, out_features=2, bias=True)
# )
# ===============Training Network============
# error:  tensor(0.)
# ===============Gathering Network============
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-535e0120ef4f> in <module>()
#      41     xylim = 1.0
#      42
# ---> 43     unique_relu_configs_list, unique_bin_acts, _, _ = utils.get_unique_relu_configs(network, xylim, num_pts)
#      44     unique_polytopes.append(len(unique_bin_acts))
#      45     print('number of polytopes:', len(unique_bin_acts))
#
# ~/Github/geometric-certificates/utilities.py in get_unique_relu_configs(network, xylim, numpts)
#     345         for y in np.linspace(ylim[0], ylim[1], numpts):
#     346             pt_0 = torch.Tensor([x, y]).type(torch.float32)
# --> 347             relu_configs = network.relu_config(pt_0, False)
#     348             bin_code = binarize_relu_configs(relu_configs)
#     349             bin_list = np.ndarray.tolist(bin_code)
#
# ~/Github/geometric-certificates/plnn.py in relu_config(self, x, return_pre_relus)
#      71
#      72     def relu_config(self, x, return_pre_relus=True):
# ---> 73         pre_relus = self.forward_by_layer(x)
#      74
#      75         configs = [(pre_relu.squeeze() > 0).type(torch.float32)
#
# ~/Github/geometric-certificates/plnn.py in forward_by_layer(self, x)
#     174         x = x.view(-1, self.layer_sizes[0])
#     175         for fc in self.fcs[:-1]:
# --> 176             x = fc(x)
#     177             pre_relus.append(x.clone())
#     178             x = F.relu(x)
#
# ~/Programs/anaconda3/envs/DeepL/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     489             result = self._slow_forward(*input, **kwargs)
#     490         else:
# --> 491             result = self.forward(*input, **kwargs)
#     492         for hook in self._forward_hooks.values():
#     493             hook_result = hook(self, input, result)
#
# ~/Programs/anaconda3/envs/DeepL/lib/python3.6/site-packages/torch/nn/modules/linear.py in forward(self, input)
#      53
#      54     def forward(self, input):
# ---> 55         return F.linear(input, self.weight, self.bias)
#      56
#      57     def extra_repr(self):
#
# ~/Programs/anaconda3/envs/DeepL/lib/python3.6/site-packages/torch/nn/functional.py in linear(input, weight, bias)
#     990     if input.dim() == 2 and bias is not None:
#     991         # fused op is marginally faster
# --> 992         return torch.addmm(bias, input, weight.t())
#     993
#     994     output = input.matmul(weight.t())
#
# KeyboardInterrupt:

# %%
xs = [6, 12, 19, 26, 32, 39, 46, 53, 59, 66, 73, 79, 86]
ys = [24, 47, 225, 255, 712, 1203, 579, 1547, 1940, 2338, 1168, 2443, 2592]


plt.figure()
import matplotlib.pyplot as plt
plt.plot(xs,ys)
plt.plot(np.unique(xs), np.poly1d(np.polyfit(xs, ys, 1))(np.unique(xs)))

# %%
plt.plot(xs,errs[0:-1])
