# %%
# ==================================
# Experiment 2
# ==================================

# demonstration to find the maximal l_p ball at a point x_0, within which,
# the class label of a random classifier is equal to C(x_0).
# network is trained to classify random points in R^2. The effects of l_1
# regularization in training are demonstrated.

# %%
# =====================
# Imports
# =====================

from geocert import compute_boundary_batch, batch_GeoCert, incremental_GeoCert
from plnn import PLNN
from _polytope_ import Polytope, from_polytope_dict
import utilities as utils
import os
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.autograd import Variable
from torchvision import datasets, transforms
# from convex_adversarial import robust_loss
# Out:
# C:\Users\justin\Anaconda3\envs\DeepL\lib\site-packages\matplotlib\figure.py:98: MatplotlibDeprecationWarning:
# Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   "Adding an axes using the same arguments as a previous axes "

# %%
# apply incremental geocert to a normal and l1-regularized classifier. Finds maximal l_p balls
# for random points in R^2.

# ==================================
# Generate Training Points
# ==================================

print('===============Generating Training Points============')
# random points at least 2r apart
m = 12
np.random.seed(3)
x = [np.random.uniform(size=(2))]
r = 0.1
while(len(x) < m):
    p = np.random.uniform(size=(2))
    if min(np.abs(p-a).sum() for a in x) > 2*r:
        x.append(p)

epsilon = r/2

X = torch.Tensor(np.array(x))
torch.manual_seed(1)
y = (torch.rand(m)+0.5).long()

print('===============Points Generated============')
# Out:
# ===============Generating Training Points============
# ===============Points Generated============

# %%
# ==================================
# Initialize Network
# ==================================

print('===============Initializing Network============')
layer_sizes = [2, 8, 2, 2]
network = PLNN(layer_sizes)
net = network.net


# ==================================
# Train Network
# ==================================

print('===============Training Network============')
opt = optim.Adam(net.parameters(), lr=1e-3)
for i in range(1000):
    out = net(Variable(X))
    l = nn.CrossEntropyLoss()(out, Variable(y))
    err = (out.max(1)[1].data != y).float().mean()
    if i % 100 == 0:
        print('error:', err)
    opt.zero_grad()
    (l).backward()
    opt.step()

# ==================================
# Visualize:  classifier boundary
# ==================================

XX, YY = np.meshgrid(np.linspace(0, 1, 100), np.linspace(0, 1, 100))
X0 = Variable(torch.Tensor(np.stack([np.ravel(XX), np.ravel(YY)]).T))
y0 = network(X0)
ZZ = (y0[:,0] - y0[:,1]).resize(100, 100).data.numpy()

_, ax = plt.subplots(figsize=(8,8))
ax.contourf(XX,YY,-ZZ, cmap="coolwarm", levels=np.linspace(-1000,1000,3))
ax.scatter(X.numpy()[:,0], X.numpy()[:,1], c=y.numpy(), cmap="coolwarm", s=70)
ax.axis("equal")
ax.axis([0, 1, 0, 1])

plt.show()

# ==================================
# Visualize: baseline classifier ReLu regions
# ==================================

print('===============Collecting Polytopes============')
num_pts = 200
xylim = 1.0

unique_relu_configs_list, unique_bin_acts, _, _ = utils.get_unique_relu_configs(network, xylim, num_pts)
print('number of polytopes:', len(unique_bin_acts))
color_dict = utils.get_color_dictionary(unique_bin_acts)
polytope_list = []


for relu_configs, unique_act in zip(unique_relu_configs_list, unique_bin_acts):
    polytope_dict = network.compute_polytope_config(relu_configs, True)
    polytope = from_polytope_dict(polytope_dict)
    polytope_list.append(polytope)
    # colors.append(color_dict[unique_act])
colors = utils.get_spaced_colors(200)[0:len(polytope_list)]
x_0 = torch.Tensor([[0.3], [0.5]])

print('===============Finding Classification Boundary Facets============')

true_label = int(network(x_0).max(1)[1].item())  # what the classifier outputs

adversarial_facets = []
for polytope in polytope_list:
    polytope_adv_constraints = network.make_adversarial_constraints(polytope.config,
                                                                    true_label)

    for facet in polytope_adv_constraints:
        adversarial_facets.append(facet)


# ------------------------------
# Plot Polytopes, boundary, and lp norm
# ------------------------------

ax = plt.gca()
alpha = 0.6
xylim = 1.0

utils.plot_polytopes_2d(polytope_list, colors, alpha, xylim, ax)
utils.plot_facets_2d(adversarial_facets, xylim=xylim, ax=ax, color='black', linestyle='dashed')
plt.xlim(0.0, 1.0)
plt.ylim(0.0, 1.0)
plt.show()


# ==================================
# Find Projections
# ==================================

lp_norm = 'l_2'
ts = []
pts = x

for pt in pts:
    print('===============Finding Projection============')
    print('lp_norm: ', lp_norm)
    x_0 = torch.Tensor(pt.reshape([2, 1]))
    print(x_0)
    print('from point: ')
    print(x_0)

    ax = plt.axes()
    cwd = os.getcwd()
    print(cwd)
    plot_dir = cwd + '/plots/incremental_geocert/'

    t = incremental_GeoCert(lp_norm, network, x_0, ax, plot_dir)

    print('the final projection value:', t)
    ts.append(t)

# ==================================
# Visualize: incremental geocert projections
# ==================================

XX, YY = np.meshgrid(np.linspace(0, 1, 100), np.linspace(0, 1, 100))
X0 = Variable(torch.Tensor(np.stack([np.ravel(XX), np.ravel(YY)]).T))
y0 = network(X0)
ZZ = (y0[:,0] - y0[:,1]).resize(100,100).data.numpy()

_, ax = plt.subplots(figsize=(8,8))
ax.contourf(XX,YY,-ZZ, cmap="coolwarm", levels=np.linspace(-1000,1000,3))
ax.scatter(X.numpy()[:,0], X.numpy()[:,1], c=y.numpy(), cmap="coolwarm", s=70)
ax.axis("equal")
ax.axis([0, 1, 0, 1])

for pt, t, y in zip(pts, ts, y.numpy()):
    if lp_norm == 'l_2':
        utils.plot_l2_norm(pt, t, ax=ax)
    elif lp_norm == 'l_inf':
        utils.plot_linf_norm(pt, t, ax=ax)
    else:
        raise NotImplementedError

print('average_linf:', np.average(ts))

plt.show()
# Out:
# ===============Initializing Network============
# Sequential(
#   (1): Linear(in_features=2, out_features=8, bias=True)
#   (2): ReLU()
#   (3): Linear(in_features=8, out_features=2, bias=True)
#   (4): ReLU()
#   (5): Linear(in_features=2, out_features=2, bias=True)
# )
# ===============Training Network============
# error: tensor(0.5833)
# error: tensor(0.5833)
# error: tensor(0.4167)
# error: tensor(0.4167)
# error: tensor(0.4167)
# error: tensor(0.3333)
# error: tensor(0.2500)
# error: tensor(0.2500)
# error: tensor(0.2500)
# error: tensor(0.2500)
# C:\Users\justin\Anaconda3\envs\DeepL\lib\site-packages\torch\tensor.py:287: UserWarning: non-inplace resize is deprecated
#   warnings.warn("non-inplace resize is deprecated")
# ===============Collecting Polytopes============
# number of polytopes: 12
# ===============Finding Classification Boundary Facets============
# an unbounded polytope was plotted imperfectly
# ===============Finding Projection============
# lp_norm:  l_2
# tensor([[0.5508],
#         [0.7081]])
# from point:
# tensor([[0.5508],
#         [0.7081]])
# C:\Users\justin\Projects\geometric-certificates
# ---Initial Polytope---
# num facets:  2
# ---Opening New Polytope---
# C:\Users\justin\Anaconda3\envs\DeepL\lib\site-packages\scipy\optimize\_linprog_ip.py:273: OptimizeWarning: Solving system with option 'sym_pos':True failed. It is normal for this to happen occasionally, especially as the solution is approached. However, if you see this frequently, consider setting option 'sym_pos' to False.
#   OptimizeWarning)
# C:\Users\justin\Anaconda3\envs\DeepL\lib\site-packages\scipy\optimize\_linprog_ip.py:285: OptimizeWarning: Solving system with option 'sym_pos':False failed. This may happen occasionally, especially as the solution is approached. However, if you see this frequently, your problem may be numerically challenging. If you cannot improve the formulation, consider setting 'lstsq' to True. Consider also setting `presolve` to True, if it is not already.
#   OptimizeWarning)
# num facets:  4
# an unbounded polytope was plotted imperfectly
# an unbounded facet was plotted imperfectly
# (-0.7919716163482512, 19.388697832959288)
# (-1.9641184831478826, 52.47448183253085)
# ---Opening New Polytope---
# num facets:  5
# an unbounded polytope was plotted imperfectly
# (-0.0065825382762174645, 2.8955271934465796)
# (-0.0312569578869209, 5.239583664661282)
# ---Opening New Polytope---
# num facets:  3
# an unbounded polytope was plotted imperfectly
# (-0.0065825382762174645, 2.8955271934465796)
# (-0.0312569578869209, 5.239583664661282)
# ---Opening New Polytope---
# weve already seen that polytope
# an unbounded polytope was plotted imperfectly
# (-0.0065825382762174645, 2.8955271934465796)
# (-0.0312569578869209, 5.239583664661282)
# ---Opening New Polytope---
# weve already seen that polytope
# an unbounded polytope was plotted imperfectly
# (-0.0065825382762174645, 2.8955271934465796)
# (-0.0312569578869209, 5.239583664661282)
# ----------Minimal Projection Generated----------
# an unbounded polytope was plotted imperfectly
# (-0.0065825382762174645, 2.8955271934465796)
# (-0.0312569578869209, 5.239583664661282)
# the final projection value: 0.1597851343090215
# ===============Finding Projection============
# lp_norm:  l_2
# tensor([[0.2909],
#         [0.5108]])
# from point:
# tensor([[0.2909],
#         [0.5108]])
# C:\Users\justin\Projects\geometric-certificates
# ---Initial Polytope---
# num facets:  3
# ---Opening New Polytope---
# num facets:  4
# (-0.09582444098166765, 0.4584391984811347)
# (0.06270621832084104, 0.6805622425144826)
# ---Opening New Polytope---
# num facets:  4
# (-0.10042587911219977, 0.5550693992223091)
# (0.03702421140044161, 1.2198843878428705)
# ---Opening New Polytope---
# num facets:  3
# (-0.10042588181590986, 0.5550694560002211)
# (0.03702421140044161, 1.2198843878428705)
# ---Opening New Polytope---
# weve already seen that polytope
# (-0.10042588181590986, 0.5550694560002211)
# (0.03702421140044161, 1.2198843878428705)
# ---Opening New Polytope---
# weve already seen that polytope
# (-0.10042588181590986, 0.5550694560002211)
# (0.03702421140044161, 1.2198843878428705)
# ----------Minimal Projection Generated----------
# (-0.10042588181590986, 0.5550694560002211)
# (0.03702421140044161, 1.2198843878428705)
# the final projection value: 0.11286895614335389
# ===============Finding Projection============
# lp_norm:  l_2
# tensor([[0.8929],
#         [0.8963]])
# from point:
# tensor([[0.8929],
#         [0.8963]])
# C:\Users\justin\Projects\geometric-certificates
# ---Initial Polytope---
# num facets:  2
# ---Opening New Polytope---
# num facets:  5
# an unbounded polytope was plotted imperfectly
# an unbounded facet was plotted imperfectly
# (-0.6038122185614121, 19.379737861636105)
# (-2.281256957886921, 52.48958366466128)
# ---Opening New Polytope---
# num facets:  4
# an unbounded polytope was plotted imperfectly
# an unbounded facet was plotted imperfectly
# (-0.6038122185614121, 19.379737861636105)
# (-2.281256957886921, 52.48958366466128)
# ---Opening New Polytope---
# num facets:  1
# an unbounded polytope was plotted imperfectly
# an unbounded polytope was plotted imperfectly
# an unbounded facet was plotted imperfectly
# (-0.6038122185614121, 19.379737861636105)
# (-2.281256957886921, 52.48958366466128)
# ---Opening New Polytope---
# num facets:  4
# an unbounded polytope was plotted imperfectly
# an unbounded polytope was plotted imperfectly
# (-0.11840188253962211, 5.243733422978077)
# (-0.0312569578869209, 5.239583664661282)
# ---Opening New Polytope---
# num facets:  3
# an unbounded polytope was plotted imperfectly
# an unbounded polytope was plotted imperfectly
# (-0.11840188253962211, 5.243733422978077)
# (-0.0312569578869209, 5.239583664661282)
# ---Opening New Polytope---
# weve already seen that polytope
# an unbounded polytope was plotted imperfectly
# an unbounded polytope was plotted imperfectly
# (-0.11840188253962211, 5.243733422978077)
# (-0.0312569578869209, 5.239583664661282)
# ---Opening New Polytope---
# weve already seen that polytope
# an unbounded polytope was plotted imperfectly
# an unbounded polytope was plotted imperfectly
# (-0.11840188253962211, 5.243733422978077)
# (-0.0312569578869209, 5.239583664661282)
# ----------Minimal Projection Generated----------
# an unbounded polytope was plotted imperfectly
# an unbounded polytope was plotted imperfectly
# (-0.11840188253962211, 5.243733422978077)
# (-0.0312569578869209, 5.239583664661282)
# the final projection value: 0.5458279964178998
# ===============Finding Projection============
# lp_norm:  l_2
# tensor([[0.1256],
#         [0.2072]])
# from point:
# tensor([[0.1256],
#         [0.2072]])
# C:\Users\justin\Projects\geometric-certificates
# ---Initial Polytope---
# num facets:  4
# ---Opening New Polytope---
# num facets:  4
# (-0.13826997612707068, 0.6829615081963575)
# (-0.021411537363878838, 0.5356859630375811)
# ----------Minimal Projection Generated----------
# (-0.13826997612707068, 0.6829615081963575)
# (-0.021411537363878838, 0.5356859630375811)
# the final projection value: 0.0639149810372836
# ===============Finding Projection============
# lp_norm:  l_2
# tensor([[0.0515],
#         [0.4408]])
# from point:
# tensor([[0.0515],
#         [0.4408]])
# C:\Users\justin\Projects\geometric-certificates
# ---Initial Polytope---
# num facets:  5
# ---Opening New Polytope---
# num facets:  4
# (-2.3396502528680707, 0.5652880466662015)
# (-0.33407654856929203, 0.5505747730949817)
# ---Opening New Polytope---
# num facets:  5
# (-3.0626938892764723, 0.5997186960189825)
# (-0.45455271486585885, 3.0805742653228854)
# ---Opening New Polytope---
# num facets:  3
# (-3.0626938892764723, 0.5997186960189825)
# (-0.45455271486585885, 3.0805742653228854)
# ---Opening New Polytope---
# weve already seen that polytope
# (-3.0626938892764723, 0.5997186960189825)
# (-0.45455271486585885, 3.0805742653228854)
# ---Opening New Polytope---
# weve already seen that polytope
# (-3.0626938892764723, 0.5997186960189825)
# (-0.45455271486585885, 3.0805742653228854)
# ----------Minimal Projection Generated----------
# (-3.0626938892764723, 0.5997186960189825)
# (-0.45455271486585885, 3.0805742653228854)
# the final projection value: 0.1747863201234936
# ===============Finding Projection============
# lp_norm:  l_2
# tensor([[0.6491],
#         [0.2785]])
# from point:
# tensor([[0.6491],
#         [0.2785]])
# C:\Users\justin\Projects\geometric-certificates
# ---Initial Polytope---
# num facets:  5
# ---Opening New Polytope---
# num facets:  4
# (-0.16985650047907672, 1.346278519588484)
# (-0.03300130175586113, 0.7790710152692091)
# ---Opening New Polytope---
# num facets:  3
# (-0.16985650047907672, 1.346278519588484)
# (-0.12593201131308387, 0.7834962871528863)
# ---Opening New Polytope---
# num facets:  5
# (-0.676556951243442, 1.3704071124820254)
# (-2.2221455352711605, 0.8833159787699376)
# ---Opening New Polytope---
# weve already seen that polytope
# (-0.676556951243442, 1.3704071124820254)
# (-2.2221455352711605, 0.8833159787699376)
# ---Opening New Polytope---
# weve already seen that polytope
# (-0.676556951243442, 1.3704071124820254)
# (-2.2221455352711605, 0.8833159787699376)
# ---Opening New Polytope---
# num facets:  3
# (-0.676556951243442, 1.3704071124820254)
# (-2.2221455352711605, 0.8833159787699376)
# ---Opening New Polytope---
# num facets:  4
# (-0.676556951243442, 1.3704071124820254)
# (-2.2221455352711605, 0.8833159787699376)
# ---Opening New Polytope---
# weve already seen that polytope
# (-0.676556951243442, 1.3704071124820254)
# (-2.2221455352711605, 0.8833159787699376)
# ---Opening New Polytope---
# weve already seen that polytope
# (-0.676556951243442, 1.3704071124820254)
# (-2.2221455352711605, 0.8833159787699376)
# ---Opening New Polytope---
# num facets:  2
# an unbounded polytope was plotted imperfectly
# an unbounded facet was plotted imperfectly
# (-1.5362585204818915, 19.424140066489464)
# (-4.685037603410031, 52.60404940968619)
# ----------Minimal Projection Generated----------
# an unbounded polytope was plotted imperfectly
# an unbounded facet was plotted imperfectly
# (-1.5362585204818915, 19.424140066489464)
# (-4.685037603410031, 52.60404940968619)
# the final projection value: 0.3090240196016816
# ===============Finding Projection============
# lp_norm:  l_2
# tensor([[0.6763],
#         [0.5909]])
# from point:
# tensor([[0.6763],
#         [0.5909]])
# C:\Users\justin\Projects\geometric-certificates
# ---Initial Polytope---
# num facets:  5
# ---Opening New Polytope---
# num facets:  2
# an unbounded polytope was plotted imperfectly
# an unbounded facet was plotted imperfectly
# (-0.6038122185614121, 19.379737861636105)
# (-2.281256957886921, 52.48958366466128)
# ---Opening New Polytope---
# num facets:  3
# an unbounded polytope was plotted imperfectly
# an unbounded facet was plotted imperfectly
# (-0.6171674321859758, 19.380373824189657)
# (-2.281256957886921, 52.48958366466128)
# ---Opening New Polytope---
# num facets:  4
# an unbounded polytope was plotted imperfectly
# (-0.0065825382762174645, 2.8955271934465796)
# (-0.0312569578869209, 5.239583664661282)
# ---Opening New Polytope---
# weve already seen that polytope
# an unbounded polytope was plotted imperfectly
# (-0.0065825382762174645, 2.8955271934465796)
# (-0.0312569578869209, 5.239583664661282)
# ---Opening New Polytope---
# weve already seen that polytope
# an unbounded polytope was plotted imperfectly
# (-0.0065825382762174645, 2.8955271934465796)
# (-0.0312569578869209, 5.239583664661282)
# ----------Minimal Projection Generated----------
# an unbounded polytope was plotted imperfectly
# (-0.0065825382762174645, 2.8955271934465796)
# (-0.0312569578869209, 5.239583664661282)
# the final projection value: 0.24021841302024058
# ===============Finding Projection============
# lp_norm:  l_2
# tensor([[0.4405],
#         [0.1569]])
# from point:
# tensor([[0.4405],
#         [0.1569]])
# C:\Users\justin\Projects\geometric-certificates
# ---Initial Polytope---
# num facets:  4
# ---Opening New Polytope---
# num facets:  5
# (-0.662127556235264, 1.0673898173102891)
# (-2.204519081884013, 0.5131604576398321)
# ---Opening New Polytope---
# num facets:  5
# (-0.676556951243442, 1.3704071124820254)
# (-2.2221455352711605, 0.8833159787699376)
# ---Opening New Polytope---
# num facets:  4
# (-0.676556951243442, 1.3704071124820254)
# (-2.2221455352711605, 0.8833159787699376)
# ---Opening New Polytope---
# num facets:  3
# (-0.676556951243442, 1.3704071124820254)
# (-2.2221455352711605, 0.8833159787699376)
# ---Opening New Polytope---
# weve already seen that polytope
# (-0.676556951243442, 1.3704071124820254)
# (-2.2221455352711605, 0.8833159787699376)
# ---Opening New Polytope---
# weve already seen that polytope
# (-0.676556951243442, 1.3704071124820254)
# (-2.2221455352711605, 0.8833159787699376)
# ---Opening New Polytope---
# num facets:  3
# (-0.676556951243442, 1.3704071124820254)
# (-2.2221455352711605, 0.8833159787699376)
# ---Opening New Polytope---
# weve already seen that polytope
# (-0.676556951243442, 1.3704071124820254)
# (-2.2221455352711605, 0.8833159787699376)
# ---Opening New Polytope---
# weve already seen that polytope
# (-0.676556951243442, 1.3704071124820254)
# (-2.2221455352711605, 0.8833159787699376)
# ----------Minimal Projection Generated----------
# (-0.676556951243442, 1.3704071124820254)
# (-2.2221455352711605, 0.8833159787699376)
# the final projection value: 0.2678614217072303
# ===============Finding Projection============
# lp_norm:  l_2
# tensor([[0.3880],
#         [0.9364]])
# from point:
# tensor([[0.3880],
#         [0.9364]])
# C:\Users\justin\Projects\geometric-certificates
# ---Initial Polytope---
# num facets:  4
# ---Opening New Polytope---
# num facets:  2
# an unbounded polytope was plotted imperfectly
# an unbounded facet was plotted imperfectly
# (-0.7919716163482512, 19.388697832959288)
# (-1.9641184831478826, 52.47448183253085)
# ----------Minimal Projection Generated----------
# an unbounded polytope was plotted imperfectly
# an unbounded facet was plotted imperfectly
# (-0.7919716163482512, 19.388697832959288)
# (-1.9641184831478826, 52.47448183253085)
# the final projection value: 0.0856540490336653
# ===============Finding Projection============
# lp_norm:  l_2
# tensor([[0.9760],
#         [0.6724]])
# from point:
# tensor([[0.9760],
#         [0.6724]])
# C:\Users\justin\Projects\geometric-certificates
# ---Initial Polytope---
# num facets:  2
# ---Opening New Polytope---
# num facets:  5
# an unbounded polytope was plotted imperfectly
# an unbounded facet was plotted imperfectly
# (-0.6038122185614121, 19.379737861636105)
# (-2.281256957886921, 52.48958366466128)
# ---Opening New Polytope---
# num facets:  4
# an unbounded polytope was plotted imperfectly
# an unbounded facet was plotted imperfectly
# (-0.6038122185614121, 19.379737861636105)
# (-2.281256957886921, 52.48958366466128)
# ---Opening New Polytope---
# num facets:  1
# an unbounded polytope was plotted imperfectly
# an unbounded polytope was plotted imperfectly
# an unbounded facet was plotted imperfectly
# (-0.6038122185614121, 19.379737861636105)
# (-2.281256957886921, 52.48958366466128)
# ---Opening New Polytope---
# num facets:  3
# an unbounded polytope was plotted imperfectly
# an unbounded polytope was plotted imperfectly
# an unbounded facet was plotted imperfectly
# (-0.6038122185614121, 19.379737861636105)
# (-2.5888240794519533, 52.50422971806914)
# ---Opening New Polytope---
# num facets:  4
# an unbounded polytope was plotted imperfectly
# an unbounded polytope was plotted imperfectly
# an unbounded facet was plotted imperfectly
# (-0.6038122185614121, 19.379737861636105)
# (-3.3381729770565327, 52.539912998907454)
# ---Opening New Polytope---
# weve already seen that polytope
# an unbounded polytope was plotted imperfectly
# an unbounded polytope was plotted imperfectly
# an unbounded facet was plotted imperfectly
# (-0.6038122185614121, 19.379737861636105)
# (-3.3381729770565327, 52.539912998907454)
# ---Opening New Polytope---
# weve already seen that polytope
# an unbounded polytope was plotted imperfectly
# an unbounded polytope was plotted imperfectly
# an unbounded facet was plotted imperfectly
# (-0.6038122185614121, 19.379737861636105)
# (-3.3381729770565327, 52.539912998907454)
# ---Opening New Polytope---
# num facets:  3
# an unbounded polytope was plotted imperfectly
# an unbounded polytope was plotted imperfectly
# an unbounded facet was plotted imperfectly
# (-0.6171674321859758, 19.380373824189657)
# (-3.3381729770565327, 52.539912998907454)
# ---Opening New Polytope---
# num facets:  4
# an unbounded polytope was plotted imperfectly
# an unbounded polytope was plotted imperfectly
# an unbounded facet was plotted imperfectly
# (-0.7919716163482512, 19.388697832959288)
# (-3.3381729770565327, 52.539912998907454)
# ---Opening New Polytope---
# weve already seen that polytope
# an unbounded polytope was plotted imperfectly
# an unbounded polytope was plotted imperfectly
# an unbounded facet was plotted imperfectly
# (-0.7919716163482512, 19.388697832959288)
# (-3.3381729770565327, 52.539912998907454)
# ---Opening New Polytope---
# weve already seen that polytope
# an unbounded polytope was plotted imperfectly
# an unbounded polytope was plotted imperfectly
# (-0.11840188253962211, 5.243733422978077)
# (-1.0881729770565332, 5.289912998907454)
# ----------Minimal Projection Generated----------
# an unbounded polytope was plotted imperfectly
# an unbounded polytope was plotted imperfectly
# (-0.11840188253962211, 5.243733422978077)
# (-1.0881729770565332, 5.289912998907454)
# the final projection value: 0.550468238404942
# ===============Finding Projection============
# lp_norm:  l_2
# tensor([[0.2692],
#         [0.2918]])
# from point:
# tensor([[0.2692],
#         [0.2918]])
# C:\Users\justin\Projects\geometric-certificates
# ---Initial Polytope---
# num facets:  4
# ---Opening New Polytope---
# num facets:  4
# (-0.13826997612707068, 0.6829615081963575)
# (-0.021411537363878838, 0.5356859630375811)
# ----------Minimal Projection Generated----------
# (-0.13826997612707068, 0.6829615081963575)
# (-0.021411537363878838, 0.5356859630375811)
# the final projection value: 0.06447082089532494
# ===============Finding Projection============
# lp_norm:  l_2
# tensor([[0.4836],
#         [0.3622]])
# from point:
# tensor([[0.4836],
#         [0.3622]])
# C:\Users\justin\Projects\geometric-certificates
# ---Initial Polytope---
# num facets:  5
# ---Opening New Polytope---
# num facets:  4
# (-0.16985650047907672, 1.346278519588484)
# (-0.03300130175586113, 0.7790710152692091)
# ---Opening New Polytope---
# num facets:  4
# (-0.16985650047907672, 1.346278519588484)
# (-0.03300130175586113, 0.7790710152692091)
# ---Opening New Polytope---
# num facets:  3
# (-0.16985650047907672, 1.346278519588484)
# (-0.03300130175586113, 0.7790710152692091)
# ---Opening New Polytope---
# weve already seen that polytope
# (-0.16985650047907672, 1.346278519588484)
# (-0.03300130175586113, 0.7790710152692091)
# ---Opening New Polytope---
# weve already seen that polytope
# (-0.16985650047907672, 1.346278519588484)
# (-0.03300130175586113, 0.7790710152692091)
# ----------Minimal Projection Generated----------
# (-0.16985650047907672, 1.346278519588484)
# (-0.03300130175586113, 0.7790710152692091)
# the final projection value: 0.12428078958473537
# average_linf: 0.22493009502323938

# %%
# apply incremental geocert to a normal and l1-regularized classifier. Finds maximal l_p balls
# for random points in R^2.

# ==================================
# Generate Training Points
# ==================================

print('===============Generating Training Points============')
# random points at least 2r apart
m = 12
np.random.seed(3)
x = [np.random.uniform(size=(2))]
r = 0.16
while(len(x) < m):
    p = np.random.uniform(size=(2))
    if min(np.abs(p-a).sum() for a in x) > 2*r:
        x.append(p)
# r = 0.145
epsilon = r/2

X = torch.Tensor(np.array(x))
torch.manual_seed(1)
y = (torch.rand(m)+0.5).long()
print('===============Points Generated============')
# Out:
# ===============Generating Training Points============

# %%
# ==================================
# Initialize Network
# ==================================

print('===============Initializing Network============')
network = PLNN(layer_sizes)
net = network.net


# ==================================
# Train Network
# ==================================

def l1_loss(net):

    return sum([_.norm(p=1) for _ in net.parameters() if _.dim() > 1])


print('===============Training Network with Regularization============')
opt = optim.Adam(net.parameters(), lr=1e-3)
for i in range(1000):
    out = net(Variable(X))
    l = nn.CrossEntropyLoss()(out, Variable(y)).view([1])

    l1_scale = torch.Tensor([1e-4])
    l += l1_scale * l1_loss(net).view([1])

    err = (out.max(1)[1].data != y).float().mean()
    opt.zero_grad()
    (l).backward()
    opt.step()

print('error: ', err)



# ==================================
# Visualize:  regularized classifier boundary
# ==================================

XX, YY = np.meshgrid(np.linspace(0, 1, 100), np.linspace(0, 1, 100))
X0 = Variable(torch.Tensor(np.stack([np.ravel(XX), np.ravel(YY)]).T))
y0 = network(X0)
ZZ = (y0[:,0] - y0[:,1]).resize(100, 100).data.numpy()

_, ax = plt.subplots(figsize=(8,8))
ax.contourf(XX,YY,-ZZ, cmap="coolwarm", levels=np.linspace(-1000,1000,3))
ax.scatter(X.numpy()[:,0], X.numpy()[:,1], c=y.numpy(), cmap="coolwarm", s=70)
ax.axis("equal")
ax.axis([0, 1, 0, 1])

plt.show()

# ==================================
# Visualize: regularized classifier ReLu regions
# ==================================

print('===============Collecting Polytopes============')
num_pts = 200
xylim = 1.0

unique_relu_configs_list, unique_bin_acts, _, _ = utils.get_unique_relu_configs(network, xylim, num_pts)
print('number of polytopes:', len(unique_bin_acts))
color_dict = utils.get_color_dictionary(unique_bin_acts)
polytope_list = []


for relu_configs, unique_act in zip(unique_relu_configs_list, unique_bin_acts):
    polytope_dict = network.compute_polytope_config(relu_configs, True)
    polytope = from_polytope_dict(polytope_dict)
    polytope_list.append(polytope)
    # colors.append(color_dict[unique_act])
colors = utils.get_spaced_colors(200)[0:len(polytope_list)]
x_0 = torch.Tensor([[0.3], [0.5]])

print('===============Finding Classification Boundary Facets============')

true_label = int(network(x_0).max(1)[1].item())  # what the classifier outputs

adversarial_facets = []
for polytope in polytope_list:
    polytope_adv_constraints = network.make_adversarial_constraints(polytope.config,
                                                                    true_label)

    for facet in polytope_adv_constraints:
        adversarial_facets.append(facet)


# ------------------------------
# Plot Polytopes, boundary, and lp norm
# ------------------------------

ax = plt.gca()
alpha = 0.6
xylim = 1.0

utils.plot_polytopes_2d(polytope_list, colors, alpha, xylim, ax)
utils.plot_facets_2d(adversarial_facets, xylim=xylim, ax=ax, color='black', linestyle='dashed')
plt.xlim(0.0, 1.0)
plt.ylim(0.0, 1.0)
plt.show()


# ==================================
# Find Projections
# ==================================

lp_norm = 'l_2'
ts = []
pts = x

for pt in pts:
    print('===============Finding Projection============')
    print('lp_norm: ', lp_norm)
    x_0 = torch.Tensor(pt.reshape([2, 1]))
    print(x_0)
    print('from point: ')
    print(x_0)

    ax = plt.axes()
    cwd = os.getcwd()
    print(cwd)
    plot_dir = cwd + '/plots/incremental_geocert/'

    t = incremental_GeoCert(lp_norm, network, x_0, ax, plot_dir)

    print('the final projection value:', t)
    ts.append(t)

# ==================================
# Visualize: incremental geocert projections
# ==================================

XX, YY = np.meshgrid(np.linspace(0, 1, 100), np.linspace(0, 1, 100))
X0 = Variable(torch.Tensor(np.stack([np.ravel(XX), np.ravel(YY)]).T))
y0 = network(X0)
ZZ = (y0[:,0] - y0[:,1]).resize(100,100).data.numpy()

_, ax = plt.subplots(figsize=(8,8))
ax.contourf(XX,YY,-ZZ, cmap="coolwarm", levels=np.linspace(-1000,1000,3))
ax.scatter(X.numpy()[:,0], X.numpy()[:,1], c=y.numpy(), cmap="coolwarm", s=70)
ax.axis("equal")
ax.axis([0, 1, 0, 1])

for pt, t, y in zip(pts, ts, y.numpy()):
    if lp_norm == 'l_2':
        utils.plot_l2_norm(pt, t, ax=ax)
    elif lp_norm == 'l_inf':
        utils.plot_linf_norm(pt, t, ax=ax)
    else:
        raise NotImplementedError

print('average_linf:', np.average(ts))

plt.show()
# Out:
# ===============Initializing Network============
# Sequential(
#   (1): Linear(in_features=2, out_features=8, bias=True)
#   (2): ReLU()
#   (3): Linear(in_features=8, out_features=2, bias=True)
#   (4): ReLU()
#   (5): Linear(in_features=2, out_features=2, bias=True)
# )
# ===============Training Network with Regularization============
# error:  tensor(0.1667)
# ===============Collecting Polytopes============
# number of polytopes: 10
# ===============Finding Classification Boundary Facets============
# an unbounded polytope was plotted imperfectly
# an unbounded polytope was plotted imperfectly
# an unbounded facet was plotted imperfectly
# ===============Finding Projection============
# lp_norm:  l_2
# tensor([[0.5508],
#         [0.7081]])
# from point:
# tensor([[0.5508],
#         [0.7081]])
# C:\Users\justin\Projects\geometric-certificates
# ---Initial Polytope---
# num facets:  4
# ----------Minimal Projection Generated----------
# (-0.06350208379310551, 2.9429620092766964)
# (-0.051979050668315596, 1.962664381524236)
# the final projection value: 0.22593953718142587
# ===============Finding Projection============
# lp_norm:  l_2
# tensor([[0.2909],
#         [0.5108]])
# from point:
# tensor([[0.2909],
#         [0.5108]])
# C:\Users\justin\Projects\geometric-certificates
# ---Initial Polytope---
# num facets:  4
# ---Opening New Polytope---
# num facets:  3
# (-0.5779063321649501, 0.5731194151337932)
# (0.0749980133221522, 0.9331901878867256)
# ---Opening New Polytope---
# num facets:  4
# (-0.6921815565407974, 2.9728991270265865)
# (-0.051979050668315596, 1.962664381524236)
# ---Opening New Polytope---
# num facets:  3
# (-0.6921815565407974, 2.9728991270265865)
# (-0.051979050668315596, 1.962664381524236)
# ---Opening New Polytope---
# weve already seen that polytope
# (-0.6921815565407974, 2.9728991270265865)
# (-0.051979050668315596, 1.962664381524236)
# ---Opening New Polytope---
# weve already seen that polytope
# (-0.6921815565407974, 2.9728991270265865)
# (-0.051979050668315596, 1.962664381524236)
# ----------Minimal Projection Generated----------
# (-0.6921815565407974, 2.9728991270265865)
# (-0.051979050668315596, 1.962664381524236)
# the final projection value: 0.09047802384210336
# ===============Finding Projection============
# lp_norm:  l_2
# tensor([[0.8929],
#         [0.8963]])
# from point:
# tensor([[0.8929],
#         [0.8963]])
# C:\Users\justin\Projects\geometric-certificates
# ---Initial Polytope---
# num facets:  4
# ----------Minimal Projection Generated----------
# (-0.06350208379310551, 2.9429620092766964)
# (-0.051979050668315596, 1.962664381524236)
# the final projection value: 0.13783851202153333
# ===============Finding Projection============
# lp_norm:  l_2
# tensor([[0.1256],
#         [0.2072]])
# from point:
# tensor([[0.1256],
#         [0.2072]])
# C:\Users\justin\Projects\geometric-certificates
# ---Initial Polytope---
# num facets:  4
# ---Opening New Polytope---
# num facets:  5
# (-1.7912236145126206, 1.0142021594060973)
# (-0.7270280656403277, 0.7471828403026628)
# ---Opening New Polytope---
# num facets:  4
# (-1.7912236145126206, 1.0142021594060973)
# (-0.7355671968114581, 0.9265045948964001)
# ----------Minimal Projection Generated----------
# (-1.7912236145126206, 1.0142021594060973)
# (-0.7355671968114581, 0.9265045948964001)
# the final projection value: 0.25520004186865375
# ===============Finding Projection============
# lp_norm:  l_2
# tensor([[0.6491],
#         [0.2785]])
# from point:
# tensor([[0.6491],
#         [0.2785]])
# C:\Users\justin\Projects\geometric-certificates
# ---Initial Polytope---
# num facets:  4
# ---Opening New Polytope---
# num facets:  3
# (-0.06350208379310551, 2.9429620092766964)
# (-0.051979050668315596, 1.962664381524236)
# ----------Minimal Projection Generated----------
# (-0.06350208379310551, 2.9429620092766964)
# (-0.051979050668315596, 1.962664381524236)
# the final projection value: 0.15974185556459805
# ===============Finding Projection============
# lp_norm:  l_2
# tensor([[0.4405],
#         [0.1569]])
# from point:
# tensor([[0.4405],
#         [0.1569]])
# C:\Users\justin\Projects\geometric-certificates
# ---Initial Polytope---
# num facets:  4
# ---Opening New Polytope---
# num facets:  4
# (-0.6477824436063525, 0.726192900728728)
# (-0.18441780933988872, 0.9002593859691825)
# ---Opening New Polytope---
# num facets:  3
# (-0.6526552544942276, 0.8285219293741048)
# (-0.18441780933988872, 0.9002593859691825)
# ---Opening New Polytope---
# num facets:  5
# (-0.6781735156264946, 1.3644054131517132)
# (-0.5474044078829242, 0.9175444620902794)
# ---Opening New Polytope---
# weve already seen that polytope
# (-0.6781735156264946, 1.3644054131517132)
# (-0.5474044078829242, 0.9175444620902794)
# ---Opening New Polytope---
# weve already seen that polytope
# (-0.6781735156264946, 1.3644054131517132)
# (-0.5474044078829242, 0.9175444620902794)
# ---Opening New Polytope---
# num facets:  5
# (-1.8104675200297662, 1.4183241752661546)
# (-0.7355671968114581, 0.9265045948964001)
# ---Opening New Polytope---
# num facets:  4
# (-1.8872047017353526, 3.0298049910834703)
# (-0.7865738869599301, 1.9976450880143128)
# ----------Minimal Projection Generated----------
# (-1.8872047017353526, 3.0298049910834703)
# (-0.7865738869599301, 1.9976450880143128)
# the final projection value: 0.177626871631934
# ===============Finding Projection============
# lp_norm:  l_2
# tensor([[0.3880],
#         [0.9364]])
# from point:
# tensor([[0.3880],
#         [0.9364]])
# C:\Users\justin\Projects\geometric-certificates
# ---Initial Polytope---
# num facets:  4
# ---Opening New Polytope---
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-056bf9bad740> in <module>
#     123     plot_dir = cwd + '/plots/incremental_geocert/'
#     124
# --> 125     t = incremental_GeoCert(lp_norm, network, x_0, ax, plot_dir)
#     126
#     127     print('the final projection value:', t)
#
# ~\Projects\geometric-certificates\geocert.py in incremental_GeoCert(lp_norm, net, x, ax, plot_dir, n_colors)
#     182                 new_polytope = from_polytope_dict(new_polytope_dict)
#     183                 geocert_update_step(lp_norm, net, x, new_polytope, popped_facet, pq, true_label,
# --> 184                                     seen_to_polytope_map, seen_to_facet_map)
#     185
#     186             else:
#
# ~\Projects\geometric-certificates\geocert.py in geocert_update_step(lp_norm, net, x, polytope, popped_facet, pr_queue, true_label, seen_to_polytope_map, seen_to_facet_map)
#     199     '''
#     200
# --> 201     polytope_facets = polytope.generate_facets_configs(seen_to_polytope_map, check_feasible=True)
#     202     print('num facets: ', len(polytope_facets))
#     203
#
# ~\Projects\geometric-certificates\_polytope_.py in generate_facets_configs(self, seen_polytopes_dict, check_feasible)
#      56             facet = Face(self.ub_A, self.ub_b, [i], config=self.config)
#      57             if check_feasible:
# ---> 58                 facet.check_feasible()
#      59             facet.check_facet()
#      60
#
# ~\Projects\geometric-certificates\_polytope_.py in check_feasible(self)
#     151                                      A_eq=self.a_eq,
#     152                                      b_eq=self.b_eq,
# --> 153                                      bounds=bounds)
#     154         is_feasible = (linprog_result.status == 0)
#     155
#
# ~\Anaconda3\envs\DeepL\lib\site-packages\scipy\optimize\_linprog.py in linprog(c, A_ub, b_ub, A_eq, b_eq, bounds, method, callback, options)
#     476     x, fun, slack, con, status, message = _postprocess(
#     477         x, c_o, A_ub_o, b_ub_o, A_eq_o, b_eq_o, bounds,
# --> 478         complete, undo, status, message, tol, iteration, disp)
#     479
#     480     sol = {
#
# ~\Anaconda3\envs\DeepL\lib\site-packages\scipy\optimize\_linprog_util.py in _postprocess(x, c, A_ub, b_ub, A_eq, b_eq, bounds, complete, undo, status, message, tol, iteration, disp)
#    1320     status, message = _check_result(
#    1321         x, fun, status, slack, con,
# -> 1322         lb, ub, tol, message
#    1323     )
#    1324
#
# ~\Anaconda3\envs\DeepL\lib\site-packages\scipy\optimize\_linprog_util.py in _check_result(x, fun, status, slack, con, lb, ub, tol, message)
#    1233         # nearly basic feasible solution. Postsolving can make the solution
#    1234         #basic, however, this solution is NOT optimal
# -> 1235         raise ValueError(message)
#    1236
#    1237     return status, message
#
# ValueError: Phase 1 of the simplex method failed to find a feasible solution. The pseudo-objective function evaluates to 4.0e-11 which exceeds the required tolerance of 1e-12 for a solution to be considered 'close enough' to zero to be a basic solution. Consider increasing the tolerance to be greater than 4.0e-11. If this tolerance is unacceptably  large the problem may be infeasible.
